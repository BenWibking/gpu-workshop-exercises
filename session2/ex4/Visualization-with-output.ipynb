# %%
import yt

# %%
ds = yt.load("~/gpu-workshop-exercises/gpu128_maxgrid128_plt12987")
# Out:
# yt : [INFO     ] 2025-01-30 13:59:57,825 Parameters: current_time              = 1.0
# yt : [INFO     ] 2025-01-30 13:59:57,826 Parameters: domain_dimensions         = [128 128 128]
# yt : [INFO     ] 2025-01-30 13:59:57,828 Parameters: domain_left_edge          = [0. 0. 0.]
# yt : [INFO     ] 2025-01-30 13:59:57,832 Parameters: domain_right_edge         = [1.2 1.2 1.2]

# %%
p = yt.SlicePlot(ds, 'x', ('boxlib', 'gasDensity'), center=[0.0, 0.6, 0.6], origin="native")
p.set_log(('boxlib', 'gasDensity'), False)
p.set_figure_size(4)
# Out:
# yt : [INFO     ] 2025-01-30 13:59:58,054 xlim = 0.000000 1.200000
# yt : [INFO     ] 2025-01-30 13:59:58,055 ylim = 0.000000 1.200000
# yt : [INFO     ] 2025-01-30 13:59:58,057 xlim = 0.000000 1.200000
# yt : [INFO     ] 2025-01-30 13:59:58,057 ylim = 0.000000 1.200000
# yt : [INFO     ] 2025-01-30 13:59:58,060 Making a fixed resolution buffer of (('boxlib', 'gasDensity')) 800 by 800
# <img style="max-width:100%;max-height:100%;" src="data:image/png;base64,..."><br>
